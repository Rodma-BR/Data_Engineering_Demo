# %% [markdown]
# # Secrets

# %% [markdown]
# How to create a secret
#
# * Create an scope
#
# * Create a secret using json notation
#
#
# databricks secrets put-secret --json '{
#   "scope": "<scope-name>",
#   "key": "<key-name>",
#   "string_value": "<secret>"
# }'

# %%
# databricks secrets put-secret --json '{
#   "scope": "<scope-name>",
#   "key": "<key-name>",
#   "string_value": "<secret>"
# }'

# %%
username = dbutils.secrets.get(scope = "email", key = "bruno_personal_user")
username

# %%
dbutils.secrets.listScopes

# %%
username == 'micorreo'
